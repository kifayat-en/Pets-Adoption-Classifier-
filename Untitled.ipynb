# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Pet Adoption Classifier</span>
# </div>

# %% [markdown]
# <div style="background-color: #f0f8ff; border-left: 6px solid #4682B4; padding: 10px; border-radius: 10px;">
#     <h3 style="color: #1e90ff">📙 About the Dataset</h3>
#     <p><strong>The Pet Adoption Dataset provides a comprehensive look into various factors that can influence the likelihood of a pet being adopted from a shelter. This dataset includes detailed information about pets available for adoption, covering various characteristics and attributes.</strong></p>
#      <h3 style="color: #1e90ff">Features</h3>
#     <p>PetID: Unique identifier for each pet.</p>
#     <p>PetType: Type of pet (e.g., Dog, Cat, Bird, Rabbit)</p>
#     <p>Breed: Specific breed of the pet.</p>
#     <p>AgeMonths: Age of the pet in months.</p>
#     <p>Color: Color of the pet.</p>
#     <p>Size: Size category of the pet (Small, Medium, Large).</p>
#     <p>WeightKg: Weight of the pet in kilograms.</p>
#     <p>Vaccinated: Vaccination status of the pet (0 - Not vaccinated, 1 - Vaccinated).</p>                                         <p>HealthCondition: Health condition of the pet (0 - Healthy, 1 - Medical condition)</p>
#     <p>TimeInShelterDays: Duration the pet has been in the shelter (days).</p>
#     <p>AdoptionFee: Adoption fee charged for the pet (in dollars).</p>
#     <p>PreviousOwner: Whether the pet had a previous owner (0 - No, 1 - Yes).</p>
#     <p>AdoptionLikelihood: Likelihood of the pet being adopted (0 - Unlikely, 1 - Likely).</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Libraries</span>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.model_selection import train_test_split
# Machine learning Algorithms 
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, f1_score, recall_score, classification_report
# Neural Network
import tensorflow
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
df  = pd.read_csv('pet_adoption_data.csv')
df.head()
# Out:
#    PetID PetType             Breed  AgeMonths   Color    Size   WeightKg  \
# 0    500    Bird          Parakeet        131  Orange   Large   5.039768
# 1    501  Rabbit            Rabbit         73   White   Large  16.086727
# 2    502     Dog  Golden Retriever        136  Orange  Medium   2.076286
# 3    503    Bird          Parakeet         97   White   Small   3.339423
# 4    504  Rabbit            Rabbit        123    Gray   Large  20.498100
#
#    Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  PreviousOwner  \
# 0           1                0                 27          140              0
# 1           0                0                  8          235              0
# 2           0                0                 85          385              0
# 3           0                0                 61          217              1
# 4           0                0                 28           14              1
#
#    AdoptionLikelihood
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
df.shape
# Out:
# (2007, 13)

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Check Null Values</span>
# </div>

# %%
df.isna().sum()
# Out:
# PetID                 0
# PetType               0
# Breed                 0
# AgeMonths             0
# Color                 0
# Size                  0
# WeightKg              0
# Vaccinated            0
# HealthCondition       0
# TimeInShelterDays     0
# AdoptionFee           0
# PreviousOwner         0
# AdoptionLikelihood    0
# dtype: int64

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Check Duplicates Values</span>
# </div>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Data Summarize, Check Statistical Summary, Check Correlation </span>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2007 entries, 0 to 2006
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PetID               2007 non-null   int64
#  1   PetType             2007 non-null   object
#  2   Breed               2007 non-null   object
#  3   AgeMonths           2007 non-null   int64
#  4   Color               2007 non-null   object
#  5   Size                2007 non-null   object
#  6   WeightKg            2007 non-null   float64
#  7   Vaccinated          2007 non-null   int64
#  8   HealthCondition     2007 non-null   int64
#  9   TimeInShelterDays   2007 non-null   int64
#  10  AdoptionFee         2007 non-null   int64
#  11  PreviousOwner       2007 non-null   int64
#  12  AdoptionLikelihood  2007 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 204.0+ KB

# %%
df.describe()
# Out:
#              PetID    AgeMonths     WeightKg   Vaccinated  HealthCondition  \
# count  2007.000000  2007.000000  2007.000000  2007.000000      2007.000000
# mean   1503.000000    92.279522    15.705776     0.701046         0.196313
# std     579.515315    52.148363     8.327749     0.457914         0.397307
# min     500.000000     1.000000     1.018198     0.000000         0.000000
# 25%    1001.500000    48.000000     8.730396     0.000000         0.000000
# 50%    1503.000000    94.000000    15.925416     1.000000         0.000000
# 75%    2004.500000   138.000000    22.737180     1.000000         0.000000
# max    2506.000000   179.000000    29.995628     1.000000         1.000000
#
#        TimeInShelterDays  AdoptionFee  PreviousOwner  AdoptionLikelihood
# count        2007.000000  2007.000000    2007.000000         2007.000000
# mean           43.974091   249.142003       0.301943            0.328351
# std            25.740253   142.887040       0.459215            0.469730
# min             1.000000     0.000000       0.000000            0.000000
# 25%            21.000000   127.000000       0.000000            0.000000
# 50%            45.000000   242.000000       0.000000            0.000000
# 75%            66.000000   375.000000       1.000000            1.000000
# max            89.000000   499.000000       1.000000            1.000000

# %%
df.corr()
# Out:
#                        PetID  AgeMonths  WeightKg  Vaccinated  \
# PetID               1.000000  -0.008464  0.034315    0.008808
# AgeMonths          -0.008464   1.000000 -0.029189   -0.001801
# WeightKg            0.034315  -0.029189  1.000000    0.022526
# Vaccinated          0.008808  -0.001801  0.022526    1.000000
# HealthCondition     0.010486   0.017200  0.000708    0.024079
# TimeInShelterDays   0.017683   0.036837 -0.000980   -0.001123
# AdoptionFee         0.010557  -0.038129 -0.002367    0.021662
# PreviousOwner       0.001339   0.034943 -0.049155   -0.011460
# AdoptionLikelihood  0.049582  -0.202209  0.017601    0.301311
#
#                     HealthCondition  TimeInShelterDays  AdoptionFee  \
# PetID                      0.010486           0.017683     0.010557
# AgeMonths                  0.017200           0.036837    -0.038129
# WeightKg                   0.000708          -0.000980    -0.002367
# Vaccinated                 0.024079          -0.001123     0.021662
# HealthCondition            1.000000          -0.012664    -0.002537
# TimeInShelterDays         -0.012664           1.000000    -0.007104
# AdoptionFee               -0.002537          -0.007104     1.000000
# PreviousOwner              0.013755           0.007958     0.009755
# AdoptionLikelihood        -0.244061           0.008867    -0.005486
#
#                     PreviousOwner  AdoptionLikelihood
# PetID                    0.001339            0.049582
# AgeMonths                0.034943           -0.202209
# WeightKg                -0.049155            0.017601
# Vaccinated              -0.011460            0.301311
# HealthCondition          0.013755           -0.244061
# TimeInShelterDays        0.007958            0.008867
# AdoptionFee              0.009755           -0.005486
# PreviousOwner            1.000000           -0.023065
# AdoptionLikelihood      -0.023065            1.000000

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">EDA</span>
# </div>

# %% [markdown]
# - Exploratory Data Analysis (Data Visualization)

# %%
df['AdoptionLikelihood'].value_counts()
# Out:
# 0    1348
# 1     659
# Name: AdoptionLikelihood, dtype: int64

# %%
plt.figure(figsize=(11,6))
sns.countplot(x=df['AdoptionLikelihood'],palette='vlag', edgecolor='black')
plt.title('Distribution of Adoption Likelihood', fontsize=15)
plt.xlabel('Adoption Likelihood', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
df['PetType'].value_counts()
# Out:
# Dog       522
# Cat       505
# Rabbit    493
# Bird      487
# Name: PetType, dtype: int64

# %%
plt.figure(figsize=(11,6))
sns.countplot(x=df['PetType'],palette='jet_r', edgecolor='black', hue=df['Color'])
plt.title('Distribution of Pet Types with Color', fontsize=15)
plt.xlabel('PetType', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.countplot(x=df['PetType'],palette='jet_r', edgecolor='black', hue=df['AdoptionLikelihood'])
plt.title('Distribution of Pet Types with Adoption Likelihood', fontsize=15)
plt.xlabel('PetType', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.countplot(x=df['Breed'],palette='winter', edgecolor='black')
plt.title('Distribution of Breed', fontsize=15)
plt.xlabel('Breed', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.countplot(x=df['Size'],palette='copper', edgecolor='black', hue=df['AdoptionLikelihood'])
plt.title('Distribution of Size with Adoption Likelihood', fontsize=15)
plt.xlabel('Size', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.scatterplot(x=df['AgeMonths'], y=df['WeightKg'], s=100, alpha=0.9, hue=df['AdoptionLikelihood'], palette='Reds')
plt.title('Scatterplot of Age Months Vs Weight Kg with Adoption Likelihood', fontsize=15)
plt.xlabel('Age Months', fontsize=12)
plt.ylabel('Weight Kg', fontsize=12)
plt.legend()
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(15,20))
for c, cols in enumerate(['AgeMonths','WeightKg',
       'Vaccinated', 'HealthCondition', 'TimeInShelterDays', 'AdoptionFee',
       'PreviousOwner', 'AdoptionLikelihood']):
    plt.subplot(4, 2, c+1)
    sns.kdeplot(x=cols, data=df, color='black', shade=True)
    plt.title(f"Distribution Of {cols}")
    plt.grid(axis='y', linestyle='--')
    plt.tight_layout(pad=4.0)
    
plt.show()

# %%
plt.figure(figsize=(15,20))
for c, cols in enumerate(['AgeMonths','WeightKg',
       'Vaccinated', 'HealthCondition', 'TimeInShelterDays', 'AdoptionFee',
       'PreviousOwner', 'AdoptionLikelihood']):
    plt.subplot(4, 2, c+1)
    sns.boxplot(x=cols, data=df, color='steelblue')
    plt.title(f"{cols}")
    plt.grid(axis='y', linestyle='--')
    plt.tight_layout(pad=4.0)
    
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.heatmap(df.corr(),annot=True, cmap='vlag')
plt.title('Correlation Metrics Of Numerical Features', fontsize=15)

plt.show()

# %%
X = df[['PetType', 'Breed', 'AgeMonths', 'Color', 'Size', 'WeightKg',
       'Vaccinated', 'HealthCondition', 'TimeInShelterDays', 'AdoptionFee','PreviousOwner']]
y = df['AdoptionLikelihood']

X_train,X_test, y_train,y_test = train_test_split(X,y , test_size=0.3)
print(f"X_train Shape: {X_train.shape}")
print(f"Y_train Shape: {y_train.shape}")
print(f"X_test Shape: {X_test.shape}")
print(f"y_test Shape: {y_test.shape}")
# Out:
# X_train Shape: (1404, 11)
# Y_train Shape: (1404,)
# X_test Shape: (603, 11)
# y_test Shape: (603,)

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Encoding Categorical Features</span>
# </div>

# %%
transformer = ColumnTransformer(transformers=[
    ('tran1', OneHotEncoder(sparse=False, drop='first',), ['PetType', 'Breed', 'Color']),
    ('tran2', OrdinalEncoder(categories=[['Small', 'Medium', 'Large']]), ['Size'])
], remainder='passthrough')

# %%
X_train_transformed = transformer.fit_transform(X_train)
X_test_transformed = transformer.fit_transform(X_test)

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Feature Scaling</span>
# </div>

# %%
scaler = StandardScaler()
scaler.fit(X_train_transformed, X_test_transformed)
X_train_transformed_scaled = scaler.transform(X_train_transformed)
X_test_transformed_scaled = scaler.transform(X_test_transformed)

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Machine Learning Models</span>
# </div>

# %%
classification_models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest Classifier": RandomForestClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    'XGBoost Classifier': XGBClassifier()
}

# %%
summary = []
for names, model in classification_models.items():
    model.fit(X_train_transformed_scaled, y_train)
    preds = model.predict(X_test_transformed_scaled)
    accuracy = accuracy_score(y_test, preds)
    p = precision_score(y_test, preds)
    r = recall_score(y_test, preds, average='macro')
    f = f1_score(y_test, preds,  average='macro')
    print(f"\nName: {names}")
    print(f"Accuracy: {accuracy:.2f}")   
    print(f"Precision Score: {p}")
    
    plt.figure(figsize=(6, 4))
    cm  = confusion_matrix(y_test,preds)
    sns.heatmap(cm, annot=True, cmap='vlag')
    plt.title(f"{names}-  Confution Metrics ")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()
    
    summary.append({
        'Model Name': names,
        'Test Accuracy': accuracy,
        'Test Precision': p,
        'Test Recall Score': r,
        'Test F1 Score': f
        
    })
    summary_df = pd.DataFrame(summary)

# Show all model evaluation metrics in one table
print("\nSummary:")
summary_df
# Out:
# Name: Logistic Regression
# Accuracy: 0.75
# Precision Score: 0.6379310344827587
# Name: Random Forest Classifier
# Accuracy: 0.93
# Precision Score: 0.9371428571428572
# Name: Gradient Boosting Classifier
# Accuracy: 0.93
# Precision Score: 0.9325842696629213
# Name: Naive Bayes
# Accuracy: 0.77
# Precision Score: 0.6555555555555556
# Name: Decision Tree Classifier
# Accuracy: 0.87
# Precision Score: 0.7931034482758621
# Name: XGBoost Classifier
# Accuracy: 0.92
# Precision Score: 0.9166666666666666
# Summary:
#                      Model Name  Test Accuracy  Test Precision  \
# 0           Logistic Regression       0.754561        0.637931
# 1      Random Forest Classifier       0.928690        0.937143
# 2  Gradient Boosting Classifier       0.930348        0.932584
# 3                   Naive Bayes       0.767828        0.655556
# 4      Decision Tree Classifier       0.872305        0.793103
# 5            XGBoost Classifier       0.923715        0.916667
#
#    Test Recall Score  Test F1 Score
# 0           0.705768       0.711483
# 1           0.904854       0.916300
# 2           0.908727       0.918610
# 3           0.724853       0.729492
# 4           0.859117       0.855801
# 5           0.902491       0.911119

# %%
plt.figure(figsize=(11, 6))
sns.barplot(data=summary_df, x='Model Name', y='Test Accuracy', palette='vlag', edgecolor='black')
plt.title("Model Accuracy Comparison", fontsize=14)
plt.xlabel("Model Name")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Neural Network (ANN)</span>
# </div>

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=21))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(132, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_48 (Dense)                     │ (None, 64)                  │           1,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 132)                 │           8,580 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 132)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_50 (Dense)                     │ (None, 32)                  │           4,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_51 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,533 (56.77 KB)
#  Trainable params: 14,405 (56.27 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, )

# %%
history = model.fit(X_train_transformed_scaled, y_train, validation_data=(X_test_transformed_scaled, y_test), 
                    epochs=100, callbacks=callback)
# Out:
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6221 - loss: 0.6623 - val_accuracy: 0.7463 - val_loss: 0.5758
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7081 - loss: 0.5571 - val_accuracy: 0.7529 - val_loss: 0.5351
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7356 - loss: 0.5147 - val_accuracy: 0.7695 - val_loss: 0.5038
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7592 - loss: 0.4688 - val_accuracy: 0.7662 - val_loss: 0.4781
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7660 - loss: 0.4674 - val_accuracy: 0.7960 - val_loss: 0.4629
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7837 - loss: 0.4560 - val_accuracy: 0.8043 - val_loss: 0.4521
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7913 - loss: 0.4264 - val_accuracy: 0.8242 - val_loss: 0.4251
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7973 - loss: 0.4345 - val_accuracy: 0.8474 - val_loss: 0.3917
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8145 - loss: 0.4080 - val_accuracy: 0.8624 - val_loss: 0.3665
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8356 - loss: 0.3996 - val_accuracy: 0.8657 - val_loss: 0.3533
# Epoch 11/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8516 - loss: 0.3722 - val_accuracy: 0.8756 - val_loss: 0.3367
# Epoch 12/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8737 - loss: 0.3361 - val_accuracy: 0.8839 - val_loss: 0.3215
# Epoch 13/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8760 - loss: 0.3463 - val_accuracy: 0.8939 - val_loss: 0.3114
# Epoch 14/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8753 - loss: 0.3226 - val_accuracy: 0.8806 - val_loss: 0.3150
# Epoch 15/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8852 - loss: 0.3201 - val_accuracy: 0.8756 - val_loss: 0.3031
# Epoch 16/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8787 - loss: 0.3230 - val_accuracy: 0.8972 - val_loss: 0.3070
# Epoch 17/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8962 - loss: 0.2952 - val_accuracy: 0.8988 - val_loss: 0.2995
# Epoch 18/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8934 - loss: 0.2856 - val_accuracy: 0.8972 - val_loss: 0.2954
# Epoch 19/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9030 - loss: 0.2675 - val_accuracy: 0.8988 - val_loss: 0.2947
# Epoch 20/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8815 - loss: 0.3291 - val_accuracy: 0.9005 - val_loss: 0.2940
# Epoch 21/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8945 - loss: 0.2754 - val_accuracy: 0.9022 - val_loss: 0.2861
# Epoch 22/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8893 - loss: 0.2825 - val_accuracy: 0.9055 - val_loss: 0.2815
# Epoch 23/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9142 - loss: 0.2697 - val_accuracy: 0.8988 - val_loss: 0.2888
# Epoch 24/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8968 - loss: 0.2782 - val_accuracy: 0.9104 - val_loss: 0.2774
# Epoch 25/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9091 - loss: 0.2717 - val_accuracy: 0.9154 - val_loss: 0.2810
# Epoch 26/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9114 - loss: 0.2387 - val_accuracy: 0.9055 - val_loss: 0.2829
# Epoch 27/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8933 - loss: 0.2707 - val_accuracy: 0.9088 - val_loss: 0.2861
# Epoch 28/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8985 - loss: 0.2688 - val_accuracy: 0.9121 - val_loss: 0.2801
# Epoch 29/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9002 - loss: 0.2578 - val_accuracy: 0.9121 - val_loss: 0.2851
# Epoch 30/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9097 - loss: 0.2724 - val_accuracy: 0.9104 - val_loss: 0.2826
# Epoch 31/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9181 - loss: 0.2530 - val_accuracy: 0.9088 - val_loss: 0.2910
# Epoch 32/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9148 - loss: 0.2485 - val_accuracy: 0.9055 - val_loss: 0.2936
# Epoch 33/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9155 - loss: 0.2204 - val_accuracy: 0.8988 - val_loss: 0.2926
# Epoch 34/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9044 - loss: 0.2396 - val_accuracy: 0.9038 - val_loss: 0.2939

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.title('Train, Test Accuracy', fontsize=14)
plt.plot(history.history['accuracy'], color='orange', label='Training Accuracy')
plt.plot(history.history['val_accuracy'], color='blue', label='Testing Accuracy')
plt.legend()
plt.grid(axis='y', linestyle='--')


plt.subplot(1,2,2)
plt.title('Train, Test Loss', fontsize=14)
plt.plot(history.history['loss'], color='orange', label='Training Loss')
plt.plot(history.history['val_loss'], color='blue', label='Testing Loss')
plt.legend()
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# <div style="background-color: #4682B4; padding: 10px 20px; border-radius: 30px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Model Evaluation</span>
# </div>

# %%
test_loss, test_accuracy = model.evaluate(X_test_transformed_scaled, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9162 - loss: 0.2452
# Test Accuracy: 0.9104
# Test Loss: 0.2774

# %%
y_pred = model.predict(X_test_transformed_scaled)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_pred=y_pred.round().astype(int)

# %%
print('classification report :\n', classification_report(y_test,y_pred))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       407
#            1       0.91      0.80      0.85       196
#
#     accuracy                           0.91       603
#    macro avg       0.91      0.88      0.89       603
# weighted avg       0.91      0.91      0.91       603

# %%
conf_m = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(11,6))
sns.heatmap(conf_m,annot=True, cmap='vlag')
plt.title('Nerural Network Confution Metrics', fontsize=15)
plt.xlabel('Predicted',fontsize=13)
plt.ylabel('True',fontsize=13)

plt.show()
